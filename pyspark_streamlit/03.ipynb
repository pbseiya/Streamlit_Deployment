# %%
import pandas as pd
import streamlit as st
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np
import os

# st.title('Recommendation System')
# Out:
# 2023-02-14 13:01:56.256
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
pwd
# Out:
# 'd:\\Projects\\Ai\\deployment_test\\pyspark_streamlit'

# %%
import pandas as pd
movies_path = 'https://raw.githubusercontent.com/smanihwr/ml-latest-small/master/movies.csv'
df_movies = pd.read_csv(movies_path)

# %%
df_movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
df_movies['genres'] = df_movies['genres'].str.split('|')
df_movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                                  genres
# 0     [Adventure, Animation, Children, Comedy, Fantasy]
# 1                        [Adventure, Children, Fantasy]
# 2                                     [Comedy, Romance]
# 3                              [Comedy, Drama, Romance]
# 4                                              [Comedy]
# ...                                                 ...
# 9737               [Action, Animation, Comedy, Fantasy]
# 9738                       [Animation, Comedy, Fantasy]
# 9739                                            [Drama]
# 9740                                [Action, Animation]
# 9741                                           [Comedy]
#
# [9742 rows x 3 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
df_movies['genres']
# Out:
# 0       [Adventure, Animation, Children, Comedy, Fantasy]
# 1                          [Adventure, Children, Fantasy]
# 2                                       [Comedy, Romance]
# 3                                [Comedy, Drama, Romance]
# 4                                                [Comedy]
#                               ...
# 9737                 [Action, Animation, Comedy, Fantasy]
# 9738                         [Animation, Comedy, Fantasy]
# 9739                                              [Drama]
# 9740                                  [Action, Animation]
# 9741                                             [Comedy]
# Name: genres, Length: 9742, dtype: object

# %%
mlb = MultiLabelBinarizer()
df_movies = pd.DataFrame(mlb.fit_transform(df_movies['genres']),
                        columns=mlb.classes,
                        index=df_movies['title'])

# %%
df_movies
# Out:
#                                            0   1   2   3   4   5   6   7   8   \
# title
# Toy Story (1995)                            0   0   1   1   1   1   0   0   0
# Jumanji (1995)                              0   0   1   0   1   0   0   0   0
# Grumpier Old Men (1995)                     0   0   0   0   0   1   0   0   0
# Waiting to Exhale (1995)                    0   0   0   0   0   1   0   0   1
# Father of the Bride Part II (1995)          0   0   0   0   0   1   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   0   1   0   1   0   1   0   0   0
# No Game No Life: Zero (2017)                0   0   0   1   0   1   0   0   0
# Flint (2017)                                0   0   0   0   0   0   0   0   1
# Bungo Stray Dogs: Dead Apple (2018)         0   1   0   1   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   0   1   0   0   0
#
#                                            9   10  11  12  13  14  15  16  17  \
# title
# Toy Story (1995)                            1   0   0   0   0   0   0   0   0
# Jumanji (1995)                              1   0   0   0   0   0   0   0   0
# Grumpier Old Men (1995)                     0   0   0   0   0   0   1   0   0
# Waiting to Exhale (1995)                    0   0   0   0   0   0   1   0   0
# Father of the Bride Part II (1995)          0   0   0   0   0   0   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   1   0   0   0   0   0   0   0   0
# No Game No Life: Zero (2017)                1   0   0   0   0   0   0   0   0
# Flint (2017)                                0   0   0   0   0   0   0   0   0
# Bungo Stray Dogs: Dead Apple (2018)         0   0   0   0   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   0   0   0   0   0
#
#                                            18  19
# title
# Toy Story (1995)                            0   0
# Jumanji (1995)                              0   0
# Grumpier Old Men (1995)                     0   0
# Waiting to Exhale (1995)                    0   0
# Father of the Bride Part II (1995)          0   0
# ...                                        ..  ..
# Black Butler: Book of the Atlantic (2017)   0   0
# No Game No Life: Zero (2017)                0   0
# Flint (2017)                                0   0
# Bungo Stray Dogs: Dead Apple (2018)         0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0
#
# [9742 rows x 20 columns]

# %%
movies_path = 'https://raw.githubusercontent.com/smanihwr/ml-latest-small/master/movies.csv'
df_movies = pd.read_csv(movies_path)
df_movies['genres'] = df_movies['genres'].str.split('|')
mlb = MultiLabelBinarizer()
df_movies = pd.DataFrame(mlb.fit_transform(df_movies['genres']),
                        columns=mlb.classes,
                        index=df_movies['title'])

# %%
df_movies
# Out:
#                                            0   1   2   3   4   5   6   7   8   \
# title
# Toy Story (1995)                            0   0   1   1   1   1   0   0   0
# Jumanji (1995)                              0   0   1   0   1   0   0   0   0
# Grumpier Old Men (1995)                     0   0   0   0   0   1   0   0   0
# Waiting to Exhale (1995)                    0   0   0   0   0   1   0   0   1
# Father of the Bride Part II (1995)          0   0   0   0   0   1   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   0   1   0   1   0   1   0   0   0
# No Game No Life: Zero (2017)                0   0   0   1   0   1   0   0   0
# Flint (2017)                                0   0   0   0   0   0   0   0   1
# Bungo Stray Dogs: Dead Apple (2018)         0   1   0   1   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   0   1   0   0   0
#
#                                            9   10  11  12  13  14  15  16  17  \
# title
# Toy Story (1995)                            1   0   0   0   0   0   0   0   0
# Jumanji (1995)                              1   0   0   0   0   0   0   0   0
# Grumpier Old Men (1995)                     0   0   0   0   0   0   1   0   0
# Waiting to Exhale (1995)                    0   0   0   0   0   0   1   0   0
# Father of the Bride Part II (1995)          0   0   0   0   0   0   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   1   0   0   0   0   0   0   0   0
# No Game No Life: Zero (2017)                1   0   0   0   0   0   0   0   0
# Flint (2017)                                0   0   0   0   0   0   0   0   0
# Bungo Stray Dogs: Dead Apple (2018)         0   0   0   0   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   0   0   0   0   0
#
#                                            18  19
# title
# Toy Story (1995)                            0   0
# Jumanji (1995)                              0   0
# Grumpier Old Men (1995)                     0   0
# Waiting to Exhale (1995)                    0   0
# Father of the Bride Part II (1995)          0   0
# ...                                        ..  ..
# Black Butler: Book of the Atlantic (2017)   0   0
# No Game No Life: Zero (2017)                0   0
# Flint (2017)                                0   0
# Bungo Stray Dogs: Dead Apple (2018)         0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0
#
# [9742 rows x 20 columns]

# %%
df_movies.iloc[:,1:]
# Out:
#                                            1   2   3   4   5   6   7   8   9   \
# title
# Toy Story (1995)                            0   1   1   1   1   0   0   0   1
# Jumanji (1995)                              0   1   0   1   0   0   0   0   1
# Grumpier Old Men (1995)                     0   0   0   0   1   0   0   0   0
# Waiting to Exhale (1995)                    0   0   0   0   1   0   0   1   0
# Father of the Bride Part II (1995)          0   0   0   0   1   0   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   1   0   1   0   1   0   0   0   1
# No Game No Life: Zero (2017)                0   0   1   0   1   0   0   0   1
# Flint (2017)                                0   0   0   0   0   0   0   1   0
# Bungo Stray Dogs: Dead Apple (2018)         1   0   1   0   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   1   0   0   0   0
#
#                                            10  11  12  13  14  15  16  17  18  \
# title
# Toy Story (1995)                            0   0   0   0   0   0   0   0   0
# Jumanji (1995)                              0   0   0   0   0   0   0   0   0
# Grumpier Old Men (1995)                     0   0   0   0   0   1   0   0   0
# Waiting to Exhale (1995)                    0   0   0   0   0   1   0   0   0
# Father of the Bride Part II (1995)          0   0   0   0   0   0   0   0   0
# ...                                        ..  ..  ..  ..  ..  ..  ..  ..  ..
# Black Butler: Book of the Atlantic (2017)   0   0   0   0   0   0   0   0   0
# No Game No Life: Zero (2017)                0   0   0   0   0   0   0   0   0
# Flint (2017)                                0   0   0   0   0   0   0   0   0
# Bungo Stray Dogs: Dead Apple (2018)         0   0   0   0   0   0   0   0   0
# Andrew Dice Clay: Dice Rules (1991)         0   0   0   0   0   0   0   0   0
#
#                                            19
# title
# Toy Story (1995)                            0
# Jumanji (1995)                              0
# Grumpier Old Men (1995)                     0
# Waiting to Exhale (1995)                    0
# Father of the Bride Part II (1995)          0
# ...                                        ..
# Black Butler: Book of the Atlantic (2017)   0
# No Game No Life: Zero (2017)                0
# Flint (2017)                                0
# Bungo Stray Dogs: Dead Apple (2018)         0
# Andrew Dice Clay: Dice Rules (1991)         0
#
# [9742 rows x 19 columns]

# %%
user_profile = []
for genre in st.session_state['df'].columns:
    user_profile.append(st.sidebar.select_slider(genre,0,5))
# Out:
# 2023-02-14 13:02:40.716 Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\streamlit\runtime\state\session_state.py:436, in SessionState.__getitem__(self, key)
#     435 try:
# --> 436     return self._getitem(widget_id, key)
#     437 except KeyError:
#
# File d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\streamlit\runtime\state\session_state.py:481, in SessionState._getitem(self, widget_id, user_key)
#     480 # We'll never get here
# --> 481 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 user_profile = []
# ----> 2 for genre in st.session_state['df'].columns:
#       3     user_profile.append(st.sidebar.select_slider(genre,0,5))
#
# File d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:89, in SessionStateProxy.__getitem__(self, key)
#      87 key = str(key)
#      88 require_valid_user_key(key)
# ---> 89 return get_session_state()[key]
#
# File d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\streamlit\runtime\state\safe_session_state.py:110, in SafeSessionState.__getitem__(self, key)
#     107 if self._disconnected:
#     108     raise KeyError(key)
# --> 110 return self._state[key]
#
# File d:\Anaconda3\envs\PYSPARK_PYTHON\lib\site-packages\streamlit\runtime\state\session_state.py:438, in SessionState.__getitem__(self, key)
#     436     return self._getitem(widget_id, key)
#     437 except KeyError:
# --> 438     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "df". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
